# %% [markdown]
# ## Gráficos de correntes I1 e I2 em função da frequência

# %%
from math import *
from cmath import *
from numpy import linalg
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2. Código do modelo numérico

# %%
R1 = 289e-3
R2 = 270.5e-3
L1 = 87.66e-6
L2 = 87.92e-6
C1 = C2 = 1e-6

RC = 100
f = 1/(2*np.pi*np.sqrt(C1*L1))
k = 0.5

w = 2*pi*f
M = k*sqrt(L1*L2)

XL1 = w * L1 * 1j
XL2 = w * L2 * 1j

XC1 = 1/(w * C1 * 1j)
XC2 = 1/(w * C2 * 1j)

XM = w * M * 1j

ZEQ = (RC * XC2)/(RC + XC2)

print("Frequência", f)
print("W = ", w)
print("M = ", M)
print("XL1 = ", XL1)
print("XL2 = ", XL2)
print("XC1 = ", XC1)
print("XC2 = ", XC2)
print("XM = ", XM)
print("ZEQ = ", ZEQ)
# Out:
# Frequência 16998.84439663996
# W =  106806.88935200025
# M =  (4.389495187376334e-05+0j)
# XL1 =  9.362691920596342j
# XL2 =  9.39046171182786j
# XC1 =  -9.36269192059634j
# XC2 =  -9.36269192059634j
# XM =  4.688283267892417j
# ZEQ =  (0.8689824994101704-9.281331766332668j)

# %%
vp = 9
V1 = (2/np.pi)*vp

# %%
def CalcularTransformador(v1, ZEQ):
    Z=np.array([[R1+XL1+XC1, -XM],[-XM, XL2+R2+ZEQ]])
    V=np.array([v1,0])
    I=np.dot(linalg.inv(Z),V)
    return I[0], I[1]
I1, I2 = CalcularTransformador(V1, ZEQ)
V2 = I2 * ZEQ
print(I1, I2)
print(V2)
# Out:
# (0.29268608326320994+0.02761347712716367j) (0.0017021784806399514+1.204063694680042j)
# (11.176793781432302+1.0305117956477758j)

# %% [markdown]
# #### 3. Construção de gráficos de I1 e I2 em função da frequência

# %%
fs = np.linspace(1, 100000, 100)
I1_list = []
I2_list = []

for f in fs:
    w = 2*np.pi*f
    XL1 = w * L1 * 1j
    XL2 = w * L2 * 1j
    XC1 = 1/(w * C1 * 1j)
    XC2 = 1/(w * C2 * 1j)
    XM = w * M * 1j

    I1, I2 = CalcularTransformador(V1, ZEQ)
    I1_list.append(np.abs(I1))
    I2_list.append(np.abs(I2))


plt.plot(fs, I1_list)
plt.plot(fs, I2_list)
plt.xlabel('Frequência (Hz)')
plt.ylabel('Corrente (A)')
plt.legend(['I1', 'I2'])
plt.grid()
plt.show()

# %% [markdown]
# #### 4. Construção de um gráfico do módulo da tensão 𝑉2 pela frequência de ressonância, para 6 diferentes indutâncias

# %%
L_values = [100e-6, 200e-6, 300e-6, 400e-6, 500e-6, 600e-6]
fr_values = np.linspace(0, 100e3, 1000) 
R1 = 289e-3
R2 = 270.5e-3
k = 0.5

for L in L_values:
    L1 = L2 = L
    V2_values = []
    for fr in fr_values:
        w = 2 * np.pi * fr
        if w == 0:
            C1 = C2 = np.inf
            XC1 = XC2 = 0
        else:
            C1 = C2 = 1 / ((w ** 2) * L1)
            XL1 = w * L1 * 1j
            XL2 = w * L2 * 1j
            XC1 = 1 / (w * C1 * 1j)
            XC2 = 1 / (w * C2 * 1j)
        M = k * np.sqrt(L1 * L2)
        XM = w * M * 1j
        ZEQ = (RC * XC2) / (RC + XC2)
        
        I1, I2 = CalcularTransformador(V1, ZEQ)
        V2 = I2 * ZEQ
        V2_values.append(abs(V2))

    plt.plot(fr_values, V2_values, label=f'L={L*1e6:.0f} µH')

plt.xlabel("Frequência de Ressonância (Hz)")
plt.ylabel("|V2| (V)")
plt.title("Gráfico de |V2| vs frequência de ressonância para diferentes valores de L")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### 5. Construção de gráficos das potências e da eficiência em função da frequência

# %%
R1 = 289e-3
R2 = 270.5e-3
C1 = C2 = 1e-6
L1 = 87.66e-6
L2 = 87.92e-6
fr_values = np.linspace(0, 100e3, 1000)
k = 0.5

P_in_list = []
P_out_list = []
efficiency_list = []

for fr in fr_values:
    w = 2 * np.pi * fr
    if w == 0:
        XC1 = XC2 = 0
    else:
        XL1 = w * L1 * 1j
        XL2 = w * L2 * 1j
        XC1 = 1 / (w * C1 * 1j)
        XC2 = 1 / (w * C2 * 1j)
    M = k * np.sqrt(L1 * L2)
    XM = w * M * 1j
    ZEQ = (RC * XC2) / (RC + XC2)

    I1, I2 = CalcularTransformador(V1, ZEQ)
    V2 = I2 * ZEQ
    P_in = V1 * I1.conjugate() / 2
    P_out = V2 * I2.conjugate() / 2

    if P_in != 0:
        efficiency = (P_out.real / P_in.real)*100
    else:
        efficiency = 0

    P_in_list.append(P_in.real)
    P_out_list.append(P_out.real)
    efficiency_list.append(efficiency)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

ax1.plot(fr_values, P_in_list, label='Potência de Entrada')
ax1.plot(fr_values, P_out_list, label='Potência de Saída')
ax1.set_xlabel('Frequência (Hz)')
ax1.set_ylabel('Potência (W)')
ax1.set_title('Potência de Entrada e Saída vs Frequência de Ressonância')
ax1.legend()
ax1.grid(True)

ax2.plot(fr_values, efficiency_list, label='Eficiência', color='green')
ax2.set_xlabel('Frequência (Hz)')
ax2.set_ylabel('Eficiência (%)')
ax2.set_title('Eficiência vs Frequência de Ressonância')
ax2.grid(True)

#plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6. Construção de um gráfico que relacione o valor de pico da tensão no secundário (no resistor 𝑅𝐶) como coeficiente de acoplamento k

# %%
k_values = np.linspace(0, 1, 500)
R1 = 289e-3
R2 = 270.5e-3
L1 = 87.66e-6
L2 = 87.92e-6
C1 = C2 = 1e-6
f = 1/(2*np.pi*np.sqrt(C1*L1))
w = 2*pi*f

V2_list = []

for k in k_values:
    XL1 = w * L1 * 1j
    XL2 = w * L2 * 1j
    XC1 = 1 / (w * C1 * 1j)
    XC2 = 1 / (w * C2 * 1j)
    M = k * sqrt(L1*L2)
    XM = w * M * 1j
    ZEQ = (RC * XC2)/(RC + XC2)

    I1, I2 = CalcularTransformador(V1, ZEQ)
    V2 = I2 * ZEQ
    V2_list.append(abs(V2))

k_max = k_values[np.argmax(V2_list)]
V2_max = np.max(V2_list)

plt.plot(k_values, V2_list, label='V2 (Pico)')
plt.xlabel('Coeficiente de Acoplamento (k)')
plt.ylabel('Tensão no Secundário (V2 Pico)')
plt.title('V2 Pico vs Coeficiente de Acoplamento (k)')
plt.scatter(k_max, V2_max, color='red', zorder=5)
plt.annotate(f'Máximo V2 ({V2_max:.2f}) em k={k_max:.2f}', (k_max, V2_max), xytext=(0.2, V2_max-0.5), 
            arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.grid(True)
plt.legend()
plt.show()

# Para cada frequência existe uam distância ótima para transmitir energia e vice-versa!!!
# Distância para a voltagem máxima: 12.9 cm

# %% [markdown]
# #### 7. Simulação das potências reais em função de R1 (resistência no primário)

# %%
R1 = 289e-3
R2 = 270.5e-3
L1 = 87.66e-6
L2 = 87.92e-6
C1 = C2 = 1e-6
k = 0.1
f = 1/(2*np.pi*np.sqrt(C1*L1))
R1_values = np.linspace(R1, R1 + 4.5, 100)

P_in_list = []
P_out_list = []
efficiency_list = []

for R in R1_values:
    R1 = R
    w = 2 * np.pi * f
    if w == 0:
        XC1 = XC2 = 0
    else:
        XL1 = w * L1 * 1j
        XL2 = w * L2 * 1j
        XC1 = 1 / (w * C1 * 1j)
        XC2 = 1 / (w * C2 * 1j)
    M = k * np.sqrt(L1 * L2)
    XM = w * M * 1j
    ZEQ = (RC * XC2) / (RC + XC2)

    I1, I2 = CalcularTransformador(V1, ZEQ)
    V2 = I2 * ZEQ
    P_in = V1 * I1.conjugate() / 2
    P_out = V2 * I2.conjugate() / 2

    if P_in != 0:
        efficiency = (P_out.real / P_in.real)*100
    else:
        efficiency = 0

    P_in_list.append(P_in.real)
    P_out_list.append(P_out.real)
    efficiency_list.append(efficiency)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
ax1.plot(R1_values, P_in_list, label='Potência de Entrada')
ax1.plot(R1_values, P_out_list, label='Potência de Saída')
ax1.set_xlabel('Resistência (Ohm)')
ax1.set_ylabel('Potência (W)')
ax1.set_title('Potência R1 Entrada e Saída vs R1')
ax1.legend()
ax1.grid(True)

ax2.plot(R1_values, efficiency_list, label='Eficiência', color='green')
ax2.set_xlabel('Resistência (Ohms)')
ax2.set_ylabel('Eficiência (%)')
ax2.set_title('Eficiência vs R1')
ax2.grid(True)

#plt.tight_layout()
plt.show()
